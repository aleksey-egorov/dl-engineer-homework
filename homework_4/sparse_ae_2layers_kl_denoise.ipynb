# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

from utils import mnist, plot_graphs, plot_mnist
import numpy as np
import random

# %matplotlib inline

# %%
mnist_transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.5,), (0.5,)),
           ])
train_loader, valid_loader, test_loader = mnist(valid=10000, transform=mnist_transform)

# %%
class Encoder(nn.Module):
    def __init__(self, latent_size=10):
        super(Encoder, self).__init__()
        self.fc1 = nn.Linear(28*28, 256)
        self.fc2 = nn.Linear(256, latent_size)
    
    def forward(self, x):
        x = F.tanh(self.fc1(x))
        x = F.sigmoid(self.fc2(x))
        return x
    
class Decoder(nn.Module):
    def __init__(self, latent_size=10):
        super(Decoder, self).__init__()
        self.fc1 = nn.Linear(latent_size, 256)
        self.fc2 = nn.Linear(256, 28*28)
    
    def forward(self, x):
        x = F.tanh(self.fc1(x))
        x = F.tanh(self.fc2(x))
        return x

# %%
class Net(nn.Module):
    def __init__(self, latent_size=10, loss_fn=F.mse_loss, lr=1e-4, l2=0.):
        super(Net, self).__init__()
        self.latent_size = latent_size
        self.E = Encoder(latent_size)
        self.D = Decoder(latent_size)
        self.loss_fn = loss_fn
        self._rho_loss = None
        self._loss = None
        self.optim = optim.Adam(self.parameters(), lr=lr, weight_decay=l2)
        
    def forward(self, x):
        x = x.view(-1, 28*28)
        h = self.E(x)
        self.data_rho = h.mean(0)
        out = self.D(h)
        return out
    
    def decode(self, h):
        with torch.no_grad():
            return self.D(h)
    
    def rho_loss(self, rho, size_average=True):
        """
        D_KL(P||Q) = sum(p*log(p/q)) = -sum(p*log(q/p)) = -p*log(q/p) - (1-p)log((1-q)/(1-p))
        """
        dkl = - torch.log(self.data_rho) * rho - torch.log(1-self.data_rho) * (1-rho)
        if size_average:
            self._rho_loss = dkl.mean()
        else:
            self._rho_loss = dkl.sum()
        return self._rho_loss
    
    def loss(self, x, target, **kwargs):
        target = target.view(-1, 28*28)
        self._loss = self.loss_fn(x, target, **kwargs)
        return self._loss

# %%
models = {'64': Net(64)}
rho = 0.05
train_log = {k: [] for k in models}
test_log = {k: [] for k in models}

# %%
### Добавление шума

# Обнуление части пикcелей
def add_null_noise(data):    
    null_ratio = 0.4
    mp = [torch.distributions.bernoulli.Bernoulli(torch.tensor([1-null_ratio])).sample().detach().numpy() for _ in range(50*28*28)]
    mpr = torch.Tensor(mp).view(-1, 1, 28, 28) 
    return data * mpr

# Белый шум
def add_norm_noise(data):
    noise = torch.randn(50, 28*28).view(-1, 1, 28, 28).clamp(-1, 1)
    return data + noise

# Обнуление левой стороны
def remove_left_part(data):
    mpz = torch.zeros((28, 14))
    mpo = torch.ones((28, 14))
    mpr = torch.cat((mpz, mpo), 1).view(-1, 1, 28, 28) 
    return data * mpr

def some_noise(data):
    rand = random.randint(1,3)
    noise_map = {
        1 : add_null_noise,
        2 : add_norm_noise,
        3 : remove_left_part
    }
    return noise_map[rand](data)

# %%
def train(epoch, models, log=None):
    train_size = len(train_loader.sampler)
    for batch_idx, (data, _) in enumerate(train_loader):
        for model in models.values():
            model.optim.zero_grad()
            data_noised = some_noise(data)
            output = model(data_noised)
            rho_loss = model.rho_loss(rho)
            loss = model.loss(output, data) + rho_loss
            loss.backward()
            model.optim.step()
            
            #to_plot = data_noised.view(-1, 1, 28, 28).clamp(0, 1).data.numpy()
            #plot_mnist(to_plot, (5, 10))
            
            
        if batch_idx % 200 == 0:
            line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
                epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
            losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
            print(line + losses)
            
    else:
        batch_idx += 1
        line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
            epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
        losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
        if log is not None:
            for k in models:
                log[k].append((models[k]._loss, models[k]._rho_loss))
        print(line + losses)

# %%
avg_lambda = lambda l: 'loss: {:.4f}'.format(l)
rho_lambda = lambda p: 'pho_loss: {:.4f}'.format(p)
line = lambda i, l, p: '{}: '.format(i) + avg_lambda(l) + '\t' + rho_lambda(p)
    
def test(models, loader, log=None):
    test_size = len(loader.sampler)


    test_loss = {k: 0. for k in models}
    pho_loss = {k: 0. for k in models}
    with torch.no_grad():
        for data, _ in loader:
            output = {k: m(data) for k, m in models.items()}
            for k, m in models.items():
                test_loss[k] += m.loss(output[k], data, size_average=False).item() # sum up batch loss
                pho_loss[k] += m.rho_loss(rho, size_average=False).item()
    
    for k in models:
        test_loss[k] /= (test_size * 784)
        pho_loss[k] /= (test_size * models[k].latent_size)
        if log is not None:
            log[k].append((test_loss[k], pho_loss[k]))
    
    lines = '\n'.join([line(k, test_loss[k], pho_loss[k]) for k in models]) + '\n'
    report = 'Test set:\n' + lines        
    print(report)

# %%
for epoch in range(1, 21):
    for model in models.values():
        model.train()
    train(epoch, models, train_log)
    for model in models.values():
        model.eval()
    test(models, valid_loader, test_log)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Losses 64: 0.213104
# Train Epoch: 1 [10000/50000 (20%)]	Losses 64: 0.216240
# Train Epoch: 1 [20000/50000 (40%)]	Losses 64: 0.214142
# Train Epoch: 1 [30000/50000 (60%)]	Losses 64: 0.200429
# Train Epoch: 1 [40000/50000 (80%)]	Losses 64: 0.192246
# Train Epoch: 1 [50000/50000 (100%)]	Losses 64: 0.171291
# Test set:
# 64: loss: 0.1813	pho_loss: 0.0040
#
# Train Epoch: 2 [0/50000 (0%)]	Losses 64: 0.176393
# Train Epoch: 2 [10000/50000 (20%)]	Losses 64: 0.177170
# Train Epoch: 2 [20000/50000 (40%)]	Losses 64: 0.173091
# Train Epoch: 2 [30000/50000 (60%)]	Losses 64: 0.176858
# Train Epoch: 2 [40000/50000 (80%)]	Losses 64: 0.182600
# Train Epoch: 2 [50000/50000 (100%)]	Losses 64: 0.154498
# Test set:
# 64: loss: 0.1562	pho_loss: 0.0040
#
# Train Epoch: 3 [0/50000 (0%)]	Losses 64: 0.161631
# Train Epoch: 3 [10000/50000 (20%)]	Losses 64: 0.153781
# Train Epoch: 3 [20000/50000 (40%)]	Losses 64: 0.150834
# Train Epoch: 3 [30000/50000 (60%)]	Losses 64: 0.161058
# Train Epoch: 3 [40000/50000 (80%)]	Losses 64: 0.162743
# Train Epoch: 3 [50000/50000 (100%)]	Losses 64: 0.148690
# Test set:
# 64: loss: 0.1421	pho_loss: 0.0040
#
# Train Epoch: 4 [0/50000 (0%)]	Losses 64: 0.147471
# Train Epoch: 4 [10000/50000 (20%)]	Losses 64: 0.139076
# Train Epoch: 4 [20000/50000 (40%)]	Losses 64: 0.151602
# Train Epoch: 4 [30000/50000 (60%)]	Losses 64: 0.149132
# Train Epoch: 4 [40000/50000 (80%)]	Losses 64: 0.132842
# Train Epoch: 4 [50000/50000 (100%)]	Losses 64: 0.132027
# Test set:
# 64: loss: 0.1297	pho_loss: 0.0040
#
# Train Epoch: 5 [0/50000 (0%)]	Losses 64: 0.120335
# Train Epoch: 5 [10000/50000 (20%)]	Losses 64: 0.133879
# Train Epoch: 5 [20000/50000 (40%)]	Losses 64: 0.124314
# Train Epoch: 5 [30000/50000 (60%)]	Losses 64: 0.122523
# Train Epoch: 5 [40000/50000 (80%)]	Losses 64: 0.134795
# Train Epoch: 5 [50000/50000 (100%)]	Losses 64: 0.141878
# Test set:
# 64: loss: 0.1185	pho_loss: 0.0040
#
# Train Epoch: 6 [0/50000 (0%)]	Losses 64: 0.128020
# Train Epoch: 6 [10000/50000 (20%)]	Losses 64: 0.122234
# Train Epoch: 6 [20000/50000 (40%)]	Losses 64: 0.131837
# Train Epoch: 6 [30000/50000 (60%)]	Losses 64: 0.119854
# Train Epoch: 6 [40000/50000 (80%)]	Losses 64: 0.140875
# Train Epoch: 6 [50000/50000 (100%)]	Losses 64: 0.119554
# Test set:
# 64: loss: 0.1096	pho_loss: 0.0040
#
# Train Epoch: 7 [0/50000 (0%)]	Losses 64: 0.119139
# Train Epoch: 7 [10000/50000 (20%)]	Losses 64: 0.120538
# Train Epoch: 7 [20000/50000 (40%)]	Losses 64: 0.117169
# Train Epoch: 7 [30000/50000 (60%)]	Losses 64: 0.118906
# Train Epoch: 7 [40000/50000 (80%)]	Losses 64: 0.104143
# Train Epoch: 7 [50000/50000 (100%)]	Losses 64: 0.131628
# Test set:
# 64: loss: 0.1028	pho_loss: 0.0040
#
# Train Epoch: 8 [0/50000 (0%)]	Losses 64: 0.125374
# Train Epoch: 8 [10000/50000 (20%)]	Losses 64: 0.116809
# Train Epoch: 8 [20000/50000 (40%)]	Losses 64: 0.121300
# Train Epoch: 8 [30000/50000 (60%)]	Losses 64: 0.113591
# Train Epoch: 8 [40000/50000 (80%)]	Losses 64: 0.122143
# Train Epoch: 8 [50000/50000 (100%)]	Losses 64: 0.119318
# Test set:
# 64: loss: 0.0969	pho_loss: 0.0040
#
# Train Epoch: 9 [0/50000 (0%)]	Losses 64: 0.108792
# Train Epoch: 9 [10000/50000 (20%)]	Losses 64: 0.108939
# Train Epoch: 9 [20000/50000 (40%)]	Losses 64: 0.091419
# Train Epoch: 9 [30000/50000 (60%)]	Losses 64: 0.096274
# Train Epoch: 9 [40000/50000 (80%)]	Losses 64: 0.112800
# Train Epoch: 9 [50000/50000 (100%)]	Losses 64: 0.092510
# Test set:
# 64: loss: 0.0933	pho_loss: 0.0040
#
# Train Epoch: 10 [0/50000 (0%)]	Losses 64: 0.101079
# Train Epoch: 10 [10000/50000 (20%)]	Losses 64: 0.121260
# Train Epoch: 10 [20000/50000 (40%)]	Losses 64: 0.111868
# Train Epoch: 10 [30000/50000 (60%)]	Losses 64: 0.110186
# Train Epoch: 10 [40000/50000 (80%)]	Losses 64: 0.096290
# Train Epoch: 10 [50000/50000 (100%)]	Losses 64: 0.116529
# Test set:
# 64: loss: 0.0891	pho_loss: 0.0040
#
# Train Epoch: 11 [0/50000 (0%)]	Losses 64: 0.112375
# Train Epoch: 11 [10000/50000 (20%)]	Losses 64: 0.107400
# Train Epoch: 11 [20000/50000 (40%)]	Losses 64: 0.105788
# Train Epoch: 11 [30000/50000 (60%)]	Losses 64: 0.107015
# Train Epoch: 11 [40000/50000 (80%)]	Losses 64: 0.094733
# Train Epoch: 11 [50000/50000 (100%)]	Losses 64: 0.093328
# Test set:
# 64: loss: 0.0860	pho_loss: 0.0040
#
# Train Epoch: 12 [0/50000 (0%)]	Losses 64: 0.087628
# Train Epoch: 12 [10000/50000 (20%)]	Losses 64: 0.096420
# Train Epoch: 12 [20000/50000 (40%)]	Losses 64: 0.105974
# Train Epoch: 12 [30000/50000 (60%)]	Losses 64: 0.090012
# Train Epoch: 12 [40000/50000 (80%)]	Losses 64: 0.096043
# Train Epoch: 12 [50000/50000 (100%)]	Losses 64: 0.094596
# Test set:
# 64: loss: 0.0834	pho_loss: 0.0040
#
# Train Epoch: 13 [0/50000 (0%)]	Losses 64: 0.106146
# Train Epoch: 13 [10000/50000 (20%)]	Losses 64: 0.107008
# Train Epoch: 13 [20000/50000 (40%)]	Losses 64: 0.099361
# Train Epoch: 13 [30000/50000 (60%)]	Losses 64: 0.104865
# Train Epoch: 13 [40000/50000 (80%)]	Losses 64: 0.093646
# Train Epoch: 13 [50000/50000 (100%)]	Losses 64: 0.088310
# Test set:
# 64: loss: 0.0811	pho_loss: 0.0040
#
# Train Epoch: 14 [0/50000 (0%)]	Losses 64: 0.102053
# Train Epoch: 14 [10000/50000 (20%)]	Losses 64: 0.100480
# Train Epoch: 14 [20000/50000 (40%)]	Losses 64: 0.086846
# Train Epoch: 14 [30000/50000 (60%)]	Losses 64: 0.112359
# Train Epoch: 14 [40000/50000 (80%)]	Losses 64: 0.097216
# Train Epoch: 14 [50000/50000 (100%)]	Losses 64: 0.094186
# Test set:
# 64: loss: 0.0789	pho_loss: 0.0040
#
# Train Epoch: 15 [0/50000 (0%)]	Losses 64: 0.102677
# Train Epoch: 15 [10000/50000 (20%)]	Losses 64: 0.087913
# Train Epoch: 15 [20000/50000 (40%)]	Losses 64: 0.090371
# Train Epoch: 15 [30000/50000 (60%)]	Losses 64: 0.102478
# Train Epoch: 15 [40000/50000 (80%)]	Losses 64: 0.089795
# Train Epoch: 15 [50000/50000 (100%)]	Losses 64: 0.097706
# Test set:
# 64: loss: 0.0768	pho_loss: 0.0040
#
# Train Epoch: 16 [0/50000 (0%)]	Losses 64: 0.094825
# Train Epoch: 16 [10000/50000 (20%)]	Losses 64: 0.081708
# Train Epoch: 16 [20000/50000 (40%)]	Losses 64: 0.095246
# Train Epoch: 16 [30000/50000 (60%)]	Losses 64: 0.083888
# Train Epoch: 16 [40000/50000 (80%)]	Losses 64: 0.085597
# Train Epoch: 16 [50000/50000 (100%)]	Losses 64: 0.087606
# Test set:
# 64: loss: 0.0749	pho_loss: 0.0040
#
# Train Epoch: 17 [0/50000 (0%)]	Losses 64: 0.084630
# Train Epoch: 17 [10000/50000 (20%)]	Losses 64: 0.080602
# Train Epoch: 17 [20000/50000 (40%)]	Losses 64: 0.077279
# Train Epoch: 17 [30000/50000 (60%)]	Losses 64: 0.094675
# Train Epoch: 17 [40000/50000 (80%)]	Losses 64: 0.088558
# Train Epoch: 17 [50000/50000 (100%)]	Losses 64: 0.076031
# Test set:
# 64: loss: 0.0732	pho_loss: 0.0040
#
# Train Epoch: 18 [0/50000 (0%)]	Losses 64: 0.075147
# Train Epoch: 18 [10000/50000 (20%)]	Losses 64: 0.081229
# Train Epoch: 18 [20000/50000 (40%)]	Losses 64: 0.092906
# Train Epoch: 18 [30000/50000 (60%)]	Losses 64: 0.092883
# Train Epoch: 18 [40000/50000 (80%)]	Losses 64: 0.080206
# Train Epoch: 18 [50000/50000 (100%)]	Losses 64: 0.096384
# Test set:
# 64: loss: 0.0716	pho_loss: 0.0040
#
# Train Epoch: 19 [0/50000 (0%)]	Losses 64: 0.080651
# Train Epoch: 19 [10000/50000 (20%)]	Losses 64: 0.087862
# Train Epoch: 19 [20000/50000 (40%)]	Losses 64: 0.078667
# Train Epoch: 19 [30000/50000 (60%)]	Losses 64: 0.072241
# Train Epoch: 19 [40000/50000 (80%)]	Losses 64: 0.102207
# Train Epoch: 19 [50000/50000 (100%)]	Losses 64: 0.076867
# Test set:
# 64: loss: 0.0703	pho_loss: 0.0040
#
# Train Epoch: 20 [0/50000 (0%)]	Losses 64: 0.082514
# Train Epoch: 20 [10000/50000 (20%)]	Losses 64: 0.079893
# Train Epoch: 20 [20000/50000 (40%)]	Losses 64: 0.083443
# Train Epoch: 20 [30000/50000 (60%)]	Losses 64: 0.091441
# Train Epoch: 20 [40000/50000 (80%)]	Losses 64: 0.083235

# %%
torch.save(models['64'], './model_64_dn')

# %% [markdown]
# ### Вывод результатов

# %%
model = torch.load('./model_64_dn')

# %%
data, _ = next(iter(test_loader))
output = model(data)
to_plot = output.view(-1, 1, 28, 28).clamp(0, 1).data.numpy()
decoded = model.decode(torch.eye(64))
dec_to_plot = ((decoded.view(-1, 1, 28, 28)+1)*0.5).clamp(0, 1).data.numpy()
with torch.no_grad():
    encoded = model.E(data.view(-1, 28*28))
    print((encoded > 0.2).sum(1))
    encoded[encoded < 0.2] = 0.
    decoded_f = model.decode(encoded)
    f_to_plot = ((decoded_f.view(-1, 1, 28, 28)+1)*0.5).clamp(0, 1).data.numpy()

# %%
plot_mnist(data.data.numpy(), (5, 10))
plot_mnist(to_plot, (5, 10))
plot_mnist(f_to_plot, (5, 10))
plot_mnist(dec_to_plot, (8, 8))

# %%
data, _ = next(iter(test_loader))
noise = torch.randn(50, 28*28).view(-1, 1, 28, 28).clamp(-1, 1)
data += noise

# %%
output = model(data)
to_plot = output.view(-1, 1, 28, 28).clamp(0, 1).data.numpy()

with torch.no_grad():
    encoded = model.E(data.view(-1, 28*28))
    print((encoded > 0.2).sum(1))
# Out:
# tensor([  2,   3,   4,   3,   5,   2,   3,   4,   3,   5,  11,   1,
#           5,   6,   6,   2,   7,   4,   3,   4,   2,   9,   1,   3,
#           1,   1,   2,   2,   4,  12,   1,  18,   4,   9,   1,   5,
#           6,   7,   1,   1,   4,   3,   6,   3,   4,   3,  14,  10,
#           0,   3])

# %%
plot_mnist(data.data.numpy(), (5, 10))
plot_mnist(to_plot, (5, 10))

# %%
data, _ = next(iter(test_loader))
null_ratio = 0.4
mp = [torch.distributions.bernoulli.Bernoulli(torch.tensor([1-null_ratio])).sample().detach().numpy() for _ in range(50*28*28)]
mpr = torch.Tensor(mp).view(-1, 1, 28, 28) 

data = data * mpr

# %%
output = model(data)
to_plot = output.view(-1, 1, 28, 28).clamp(0, 1).data.numpy()
with torch.no_grad():
    encoded = model.E(data.view(-1, 28*28))
    print((encoded > 0.2).sum(1))
# Out:
# tensor([ 16,  14,   4,   7,  13,   1,   2,  12,  10,   7,   9,   5,
#           4,   7,  12,   6,  12,   5,   9,   9,   7,   6,  15,   1,
#           7,   2,  13,   1,   8,   7,   1,  12,  11,  14,   4,   9,
#           9,   5,   6,   8,   7,   9,   2,   3,   3,   7,   6,   4,
#           4,   7])

# %%
plot_mnist(data.data.numpy(), (5, 10))
plot_mnist(to_plot, (5, 10))

# %%
data, _ = next(iter(test_loader))
mpz = torch.zeros((28, 14))
mpo = torch.ones((28, 14))
mpr = torch.cat((mpz, mpo), 1).view(-1, 1, 28, 28) 

data = data * mpr

# %%
output = model(data)
to_plot = output.view(-1, 1, 28, 28).clamp(0, 1).data.numpy()
with torch.no_grad():
    encoded = model.E(data.view(-1, 28*28))
    print((encoded > 0.2).sum(1))
# Out:
# tensor([ 34,  35,  25,  28,  31,  25,  34,  32,  26,  25,  24,  27,
#          27,  27,  35,  27,  28,  28,  23,  24,  27,  37,  27,  26,
#          29,  19,  33,  30,  26,  36,  33,  30,  27,  28,  31,  26,
#          32,  30,  32,  28,  37,  35,  29,  26,  36,  25,  35,  34,
#          24,  30])

# %%
plot_mnist(data.data.numpy(), (5, 10))
plot_mnist(to_plot, (5, 10))
