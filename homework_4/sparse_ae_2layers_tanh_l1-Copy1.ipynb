# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

from utils import mnist, plot_graphs, plot_mnist
import numpy as np

# %matplotlib inline

# %%
mnist_transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.5,), (0.5,)),
           ])
train_loader, valid_loader, test_loader = mnist(valid=10000, transform=mnist_transform, batch_size=50)

# %%
class Encoder(nn.Module):
    def __init__(self, latent_size=10):
        super(Encoder, self).__init__()
        self.fc1 = nn.Linear(28*28, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, latent_size)
    
    def forward(self, x):
        x = F.tanh(self.fc1(x))
        x = F.tanh(self.fc2(x))
        x = F.tanh(self.fc3(x))
        return x
    
class Decoder(nn.Module):
    def __init__(self, latent_size=10):
        super(Decoder, self).__init__()
        self.fc1 = nn.Linear(latent_size, 256)
        self.fc2 = nn.Linear(256, 512 )
        self.fc3 = nn.Linear(512, 28*28)
    
    def forward(self, x):
        x = F.tanh(self.fc1(x))
        x = F.tanh(self.fc2(x))
        x = F.tanh(self.fc3(x))
        return x

# %%
class Net(nn.Module):
    def __init__(self, latent_size=10, loss_fn=F.mse_loss, lr=1e-4, l2=0.):
        super(Net, self).__init__()
        self.latent_size = latent_size
        self.E = Encoder(latent_size)
        self.D = Decoder(latent_size)
        self.latent = None
        self.loss_fn = loss_fn
        self._rho_loss = None
        self._loss = 0.    
        self.optim = optim.Adam(self.parameters(), lr=lr, weight_decay=l2)
        
    def forward(self, x):
        x = x.view(-1, 28*28)
        self.latent = self.E(x)
        #self.data_rho = h.mean(0)
        out = self.D(self.latent)
        return out
    
    def encode(self, x):
        with torch.no_grad():
            return self.E(x)
    
    def decode(self, h):
        with torch.no_grad():
            return self.D(h)
    
    def rho_loss(self, rho, size_average=True):        
        #self._rho_loss = F.l1_loss(self.latent, torch.eye(self.latent_size))      
        h_abs = torch.abs(self.latent.mean(0))
        self.sparse_loss = rho * h_abs.mean()
        return self.sparse_loss
    
    def loss(self, x, target, **kwargs):
        target = target.view(-1, 28*28)
        self._loss = self.loss_fn(x, target, **kwargs)
        return self._loss

# %%
models = {'50': Net(50)}
rho = 1/20
train_log = {k: [] for k in models}
test_log = {k: [] for k in models}

# %%
def train(epoch, models, log=None):
    train_size = len(train_loader.sampler)
    for batch_idx, (data, _) in enumerate(train_loader):
        for model in models.values():
            model.optim.zero_grad()
            output = model(data)
            rho_loss = model.rho_loss(rho)
            loss = model.loss(output, data) + rho_loss
            #print ("rho_loss=", rho_loss)
            loss.backward()
            model.optim.step()
            
        if batch_idx % 500 == 0:
            line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
                epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
            losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
            print(line + losses)
            
    else:
        batch_idx += 1
        line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
            epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
        losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
        if log is not None:
            for k in models:
                log[k].append((models[k]._loss, models[k]._rho_loss))
        print(line + losses)

# %%
avg_lambda = lambda l: 'loss: {:.4f}'.format(l)
rho_lambda = lambda p: 'pho_loss: {:.10f}'.format(p)
line = lambda i, l, p: '{}: '.format(i) + avg_lambda(l) + '\t' + rho_lambda(p)
    
def test(models, loader, log=None):
    test_size = len(loader.sampler)


    test_loss = {k: 0. for k in models}
    pho_loss = {k: 0. for k in models}
    with torch.no_grad():
        for data, _ in loader:
            output = {k: m(data) for k, m in models.items()}
            for k, m in models.items():
                test_loss[k] += m.loss(output[k], data, size_average=False).item() # sum up batch loss
                pho_loss[k] += m.rho_loss(rho)
               #print ("test_rho_loss=", m.rho_loss(rho))
    
    for k in models:
        test_loss[k] /= (test_size * 784)
        pho_loss[k] /= (test_size * models[k].latent_size)
        if log is not None:
            log[k].append((test_loss[k], pho_loss[k]))
    
    lines = '\n'.join([line(k, test_loss[k], pho_loss[k]) for k in models]) + '\n'
    report = 'Test set:\n' + lines        
    print(report)

# %%
for epoch in range(1, 201):
    for model in models.values():
        model.train()
    train(epoch, models, train_log)
    for model in models.values():
        model.eval()
    test(models, valid_loader, test_log)
# Out:
# /home/aleksey/.conda/envs/otus-dl-engineer/lib/python3.6/site-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Train Epoch: 1 [0/50000 (0%)]	Losses 50: 0.930779
# Train Epoch: 1 [25000/50000 (50%)]	Losses 50: 0.151003
# Train Epoch: 1 [50000/50000 (100%)]	Losses 50: 0.106894
# /home/aleksey/.conda/envs/otus-dl-engineer/lib/python3.6/site-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set:
# 50: loss: 0.1145	pho_loss: 0.0000016444
#
# Train Epoch: 2 [0/50000 (0%)]	Losses 50: 0.104203
# Train Epoch: 2 [25000/50000 (50%)]	Losses 50: 0.083964
# Train Epoch: 2 [50000/50000 (100%)]	Losses 50: 0.074870
# Test set:
# 50: loss: 0.0770	pho_loss: 0.0000011957
#
# Train Epoch: 3 [0/50000 (0%)]	Losses 50: 0.072110
# Train Epoch: 3 [25000/50000 (50%)]	Losses 50: 0.056879
# Train Epoch: 3 [50000/50000 (100%)]	Losses 50: 0.065047
# Test set:
# 50: loss: 0.0603	pho_loss: 0.0000010261
#
# Train Epoch: 4 [0/50000 (0%)]	Losses 50: 0.053993
# Train Epoch: 4 [25000/50000 (50%)]	Losses 50: 0.050897
# Train Epoch: 4 [50000/50000 (100%)]	Losses 50: 0.053047
# Test set:
# 50: loss: 0.0501	pho_loss: 0.0000009358
#
# Train Epoch: 5 [0/50000 (0%)]	Losses 50: 0.051121
# Train Epoch: 5 [25000/50000 (50%)]	Losses 50: 0.046015
# Train Epoch: 5 [50000/50000 (100%)]	Losses 50: 0.047964
# Test set:
# 50: loss: 0.0438	pho_loss: 0.0000008655
#
# Train Epoch: 6 [0/50000 (0%)]	Losses 50: 0.045792
# Train Epoch: 6 [25000/50000 (50%)]	Losses 50: 0.040679
# Train Epoch: 6 [50000/50000 (100%)]	Losses 50: 0.035821
# Test set:
# 50: loss: 0.0401	pho_loss: 0.0000008374
#
# Train Epoch: 7 [0/50000 (0%)]	Losses 50: 0.039536
# Train Epoch: 7 [25000/50000 (50%)]	Losses 50: 0.038686
# Train Epoch: 7 [50000/50000 (100%)]	Losses 50: 0.036757
# Test set:
# 50: loss: 0.0368	pho_loss: 0.0000008085
#
# Train Epoch: 8 [0/50000 (0%)]	Losses 50: 0.033874
# Train Epoch: 8 [25000/50000 (50%)]	Losses 50: 0.034369
# Train Epoch: 8 [50000/50000 (100%)]	Losses 50: 0.036168
# Test set:
# 50: loss: 0.0344	pho_loss: 0.0000007763
#
# Train Epoch: 9 [0/50000 (0%)]	Losses 50: 0.035243
# Train Epoch: 9 [25000/50000 (50%)]	Losses 50: 0.031286
# Train Epoch: 9 [50000/50000 (100%)]	Losses 50: 0.028281
# Test set:
# 50: loss: 0.0322	pho_loss: 0.0000007494
#
# Train Epoch: 10 [0/50000 (0%)]	Losses 50: 0.028499
# Train Epoch: 10 [25000/50000 (50%)]	Losses 50: 0.029442
# Train Epoch: 10 [50000/50000 (100%)]	Losses 50: 0.030662
# Test set:
# 50: loss: 0.0303	pho_loss: 0.0000007205
#
# Train Epoch: 11 [0/50000 (0%)]	Losses 50: 0.027438
# Train Epoch: 11 [25000/50000 (50%)]	Losses 50: 0.028882
# Train Epoch: 11 [50000/50000 (100%)]	Losses 50: 0.024152
# Test set:
# 50: loss: 0.0288	pho_loss: 0.0000006978
#
# Train Epoch: 12 [0/50000 (0%)]	Losses 50: 0.021886
# Train Epoch: 12 [25000/50000 (50%)]	Losses 50: 0.026553
# Train Epoch: 12 [50000/50000 (100%)]	Losses 50: 0.026820
# Test set:
# 50: loss: 0.0277	pho_loss: 0.0000006854
#
# Train Epoch: 13 [0/50000 (0%)]	Losses 50: 0.027827
# Train Epoch: 13 [25000/50000 (50%)]	Losses 50: 0.028030
# Train Epoch: 13 [50000/50000 (100%)]	Losses 50: 0.025636
# Test set:
# 50: loss: 0.0267	pho_loss: 0.0000006822
#
# Train Epoch: 14 [0/50000 (0%)]	Losses 50: 0.031620
# Train Epoch: 14 [25000/50000 (50%)]	Losses 50: 0.028847
# Train Epoch: 14 [50000/50000 (100%)]	Losses 50: 0.026494
# Test set:
# 50: loss: 0.0256	pho_loss: 0.0000006612
#
# Train Epoch: 15 [0/50000 (0%)]	Losses 50: 0.023525
# Train Epoch: 15 [25000/50000 (50%)]	Losses 50: 0.027886
# Train Epoch: 15 [50000/50000 (100%)]	Losses 50: 0.025398
# Test set:
# 50: loss: 0.0247	pho_loss: 0.0000006445
#
# Train Epoch: 16 [0/50000 (0%)]	Losses 50: 0.026273
# Train Epoch: 16 [25000/50000 (50%)]	Losses 50: 0.021082
# Train Epoch: 16 [50000/50000 (100%)]	Losses 50: 0.023123
# Test set:
# 50: loss: 0.0241	pho_loss: 0.0000006321
#
# Train Epoch: 17 [0/50000 (0%)]	Losses 50: 0.022180
# Train Epoch: 17 [25000/50000 (50%)]	Losses 50: 0.024783
# Train Epoch: 17 [50000/50000 (100%)]	Losses 50: 0.026923
# Test set:
# 50: loss: 0.0231	pho_loss: 0.0000006026
#
# Train Epoch: 18 [0/50000 (0%)]	Losses 50: 0.019882
# Train Epoch: 18 [25000/50000 (50%)]	Losses 50: 0.023918
# Train Epoch: 18 [50000/50000 (100%)]	Losses 50: 0.022412
# Test set:
# 50: loss: 0.0225	pho_loss: 0.0000006022
#
# Train Epoch: 19 [0/50000 (0%)]	Losses 50: 0.024468
# Train Epoch: 19 [25000/50000 (50%)]	Losses 50: 0.022793
# Train Epoch: 19 [50000/50000 (100%)]	Losses 50: 0.022810
# Test set:
# 50: loss: 0.0219	pho_loss: 0.0000006019
#
# Train Epoch: 20 [0/50000 (0%)]	Losses 50: 0.020550
# Train Epoch: 20 [25000/50000 (50%)]	Losses 50: 0.018949
# Train Epoch: 20 [50000/50000 (100%)]	Losses 50: 0.023596
# Test set:
# 50: loss: 0.0214	pho_loss: 0.0000005903
#
# Train Epoch: 21 [0/50000 (0%)]	Losses 50: 0.018295
# Train Epoch: 21 [25000/50000 (50%)]	Losses 50: 0.017910
# Train Epoch: 21 [50000/50000 (100%)]	Losses 50: 0.020978
# Test set:
# 50: loss: 0.0209	pho_loss: 0.0000005811
#
# Train Epoch: 22 [0/50000 (0%)]	Losses 50: 0.018304
# Train Epoch: 22 [25000/50000 (50%)]	Losses 50: 0.020075
# Train Epoch: 22 [50000/50000 (100%)]	Losses 50: 0.019079
# Test set:
# 50: loss: 0.0205	pho_loss: 0.0000005658
#
# Train Epoch: 23 [0/50000 (0%)]	Losses 50: 0.017509
# Train Epoch: 23 [25000/50000 (50%)]	Losses 50: 0.019495
# Train Epoch: 23 [50000/50000 (100%)]	Losses 50: 0.021107
# Test set:
# 50: loss: 0.0199	pho_loss: 0.0000005599
#
# Train Epoch: 24 [0/50000 (0%)]	Losses 50: 0.016849
# Train Epoch: 24 [25000/50000 (50%)]	Losses 50: 0.020010
# Train Epoch: 24 [50000/50000 (100%)]	Losses 50: 0.017096
# Test set:
# 50: loss: 0.0194	pho_loss: 0.0000005388
#
# Train Epoch: 25 [0/50000 (0%)]	Losses 50: 0.019625
# Train Epoch: 25 [25000/50000 (50%)]	Losses 50: 0.017783
# Train Epoch: 25 [50000/50000 (100%)]	Losses 50: 0.021110
# Test set:
# 50: loss: 0.0195	pho_loss: 0.0000005399
#
# Train Epoch: 26 [0/50000 (0%)]	Losses 50: 0.017799
# Train Epoch: 26 [25000/50000 (50%)]	Losses 50: 0.017682
# Train Epoch: 26 [50000/50000 (100%)]	Losses 50: 0.022501
# Test set:
# 50: loss: 0.0190	pho_loss: 0.0000005326
#
# Train Epoch: 27 [0/50000 (0%)]	Losses 50: 0.016639
# Train Epoch: 27 [25000/50000 (50%)]	Losses 50: 0.018475
# Train Epoch: 27 [50000/50000 (100%)]	Losses 50: 0.019078
# Test set:
# 50: loss: 0.0186	pho_loss: 0.0000005331
#
# Train Epoch: 28 [0/50000 (0%)]	Losses 50: 0.018238
# Train Epoch: 28 [25000/50000 (50%)]	Losses 50: 0.014032
# Train Epoch: 28 [50000/50000 (100%)]	Losses 50: 0.014904
# Test set:
# 50: loss: 0.0183	pho_loss: 0.0000005217
#
# Train Epoch: 29 [0/50000 (0%)]	Losses 50: 0.016312
# Train Epoch: 29 [25000/50000 (50%)]	Losses 50: 0.018346
# Train Epoch: 29 [50000/50000 (100%)]	Losses 50: 0.014704
# Test set:
# 50: loss: 0.0181	pho_loss: 0.0000005001
#
# Train Epoch: 30 [0/50000 (0%)]	Losses 50: 0.017331
# Train Epoch: 30 [25000/50000 (50%)]	Losses 50: 0.021640
# Train Epoch: 30 [50000/50000 (100%)]	Losses 50: 0.015902
# Test set:
# 50: loss: 0.0176	pho_loss: 0.0000005014
#
# Train Epoch: 31 [0/50000 (0%)]	Losses 50: 0.017154
# Train Epoch: 31 [25000/50000 (50%)]	Losses 50: 0.017026
# Train Epoch: 31 [50000/50000 (100%)]	Losses 50: 0.015882
# Test set:
# 50: loss: 0.0175	pho_loss: 0.0000005003
#
# Train Epoch: 32 [0/50000 (0%)]	Losses 50: 0.017766
# Train Epoch: 32 [25000/50000 (50%)]	Losses 50: 0.013424
# Train Epoch: 32 [50000/50000 (100%)]	Losses 50: 0.015426
# Test set:
# 50: loss: 0.0173	pho_loss: 0.0000005078
#
# Train Epoch: 33 [0/50000 (0%)]	Losses 50: 0.015096
# Train Epoch: 33 [25000/50000 (50%)]	Losses 50: 0.015986
# Train Epoch: 33 [50000/50000 (100%)]	Losses 50: 0.015774
# Test set:
# 50: loss: 0.0170	pho_loss: 0.0000004838
#
# Train Epoch: 34 [0/50000 (0%)]	Losses 50: 0.015520
# Train Epoch: 34 [25000/50000 (50%)]	Losses 50: 0.016916
# Train Epoch: 34 [50000/50000 (100%)]	Losses 50: 0.016001
# Test set:
# 50: loss: 0.0169	pho_loss: 0.0000005008
#
# Train Epoch: 35 [0/50000 (0%)]	Losses 50: 0.015312
# Train Epoch: 35 [25000/50000 (50%)]	Losses 50: 0.016237
# Train Epoch: 35 [50000/50000 (100%)]	Losses 50: 0.015799
# Test set:
# 50: loss: 0.0165	pho_loss: 0.0000004806
#
# Train Epoch: 36 [0/50000 (0%)]	Losses 50: 0.014493
# Train Epoch: 36 [25000/50000 (50%)]	Losses 50: 0.015189
# Train Epoch: 36 [50000/50000 (100%)]	Losses 50: 0.013480
# Test set:
# 50: loss: 0.0165	pho_loss: 0.0000004769
#
# Train Epoch: 37 [0/50000 (0%)]	Losses 50: 0.017263
# Train Epoch: 37 [25000/50000 (50%)]	Losses 50: 0.014817
# Train Epoch: 37 [50000/50000 (100%)]	Losses 50: 0.014617
# Test set:
# 50: loss: 0.0163	pho_loss: 0.0000004779
#
# Train Epoch: 38 [0/50000 (0%)]	Losses 50: 0.016345
# Train Epoch: 38 [25000/50000 (50%)]	Losses 50: 0.015252
# Train Epoch: 38 [50000/50000 (100%)]	Losses 50: 0.013626
# Test set:
# 50: loss: 0.0159	pho_loss: 0.0000004601
#
# Train Epoch: 39 [0/50000 (0%)]	Losses 50: 0.013479
# Train Epoch: 39 [25000/50000 (50%)]	Losses 50: 0.015809
# Train Epoch: 39 [50000/50000 (100%)]	Losses 50: 0.014839
# Test set:
# 50: loss: 0.0159	pho_loss: 0.0000004768
#
# Train Epoch: 40 [0/50000 (0%)]	Losses 50: 0.012159
# Train Epoch: 40 [25000/50000 (50%)]	Losses 50: 0.015995
# Train Epoch: 40 [50000/50000 (100%)]	Losses 50: 0.014073
# Test set:
# 50: loss: 0.0157	pho_loss: 0.0000004646
#
# Train Epoch: 41 [0/50000 (0%)]	Losses 50: 0.012635
# Train Epoch: 41 [25000/50000 (50%)]	Losses 50: 0.011713
# Train Epoch: 41 [50000/50000 (100%)]	Losses 50: 0.015201
# Test set:
# 50: loss: 0.0154	pho_loss: 0.0000004648
#
# Train Epoch: 42 [0/50000 (0%)]	Losses 50: 0.013438
# Train Epoch: 42 [25000/50000 (50%)]	Losses 50: 0.014736
# Train Epoch: 42 [50000/50000 (100%)]	Losses 50: 0.011363
# Test set:
# 50: loss: 0.0155	pho_loss: 0.0000004589
#
# Train Epoch: 43 [0/50000 (0%)]	Losses 50: 0.016032
# Train Epoch: 43 [25000/50000 (50%)]	Losses 50: 0.014471
# Train Epoch: 43 [50000/50000 (100%)]	Losses 50: 0.015941
# Test set:
# 50: loss: 0.0151	pho_loss: 0.0000004457
#
# Train Epoch: 44 [0/50000 (0%)]	Losses 50: 0.013129
# Train Epoch: 44 [25000/50000 (50%)]	Losses 50: 0.014001
# Train Epoch: 44 [50000/50000 (100%)]	Losses 50: 0.013487
# Test set:
# 50: loss: 0.0152	pho_loss: 0.0000004608
#
# Train Epoch: 45 [0/50000 (0%)]	Losses 50: 0.013212
# Train Epoch: 45 [25000/50000 (50%)]	Losses 50: 0.012382
# Train Epoch: 45 [50000/50000 (100%)]	Losses 50: 0.014023
# Test set:
# 50: loss: 0.0152	pho_loss: 0.0000004451
#
# Train Epoch: 46 [0/50000 (0%)]	Losses 50: 0.014678
# Train Epoch: 46 [25000/50000 (50%)]	Losses 50: 0.012301
# Train Epoch: 46 [50000/50000 (100%)]	Losses 50: 0.012045
# Test set:
# 50: loss: 0.0148	pho_loss: 0.0000004276
#
# Train Epoch: 47 [0/50000 (0%)]	Losses 50: 0.013602
# Train Epoch: 47 [25000/50000 (50%)]	Losses 50: 0.014212
# Train Epoch: 47 [50000/50000 (100%)]	Losses 50: 0.013494
# Test set:
# 50: loss: 0.0148	pho_loss: 0.0000004267
#
# Train Epoch: 48 [0/50000 (0%)]	Losses 50: 0.012709
# Train Epoch: 48 [25000/50000 (50%)]	Losses 50: 0.014742
# Train Epoch: 48 [50000/50000 (100%)]	Losses 50: 0.013252
# Test set:
# 50: loss: 0.0145	pho_loss: 0.0000004300
#
# Train Epoch: 49 [0/50000 (0%)]	Losses 50: 0.015471
# Train Epoch: 49 [25000/50000 (50%)]	Losses 50: 0.011947
# Train Epoch: 49 [50000/50000 (100%)]	Losses 50: 0.015138
# Test set:
# 50: loss: 0.0144	pho_loss: 0.0000004129
#
# Train Epoch: 50 [0/50000 (0%)]	Losses 50: 0.011525
# Train Epoch: 50 [25000/50000 (50%)]	Losses 50: 0.012117
# Train Epoch: 50 [50000/50000 (100%)]	Losses 50: 0.012486
# Test set:
# 50: loss: 0.0143	pho_loss: 0.0000004202
#
# Train Epoch: 51 [0/50000 (0%)]	Losses 50: 0.011762
# Train Epoch: 51 [25000/50000 (50%)]	Losses 50: 0.011899
# Train Epoch: 51 [50000/50000 (100%)]	Losses 50: 0.012374
# Test set:
# 50: loss: 0.0143	pho_loss: 0.0000004120
#
# Train Epoch: 52 [0/50000 (0%)]	Losses 50: 0.013338
# Train Epoch: 52 [25000/50000 (50%)]	Losses 50: 0.011596
# Train Epoch: 52 [50000/50000 (100%)]	Losses 50: 0.012488
# Test set:
# 50: loss: 0.0141	pho_loss: 0.0000004206
#
# Train Epoch: 53 [0/50000 (0%)]	Losses 50: 0.011182
# Train Epoch: 53 [25000/50000 (50%)]	Losses 50: 0.012614
# Train Epoch: 53 [50000/50000 (100%)]	Losses 50: 0.011825
# Test set:
# 50: loss: 0.0139	pho_loss: 0.0000004040
#
# Train Epoch: 54 [0/50000 (0%)]	Losses 50: 0.012877
# Train Epoch: 54 [25000/50000 (50%)]	Losses 50: 0.013766
# Train Epoch: 54 [50000/50000 (100%)]	Losses 50: 0.012388
# Test set:
# 50: loss: 0.0139	pho_loss: 0.0000004058
#
# Train Epoch: 55 [0/50000 (0%)]	Losses 50: 0.010912
# Train Epoch: 55 [25000/50000 (50%)]	Losses 50: 0.011863
# Train Epoch: 55 [50000/50000 (100%)]	Losses 50: 0.011601
# Test set:
# 50: loss: 0.0139	pho_loss: 0.0000004015
#
# Train Epoch: 56 [0/50000 (0%)]	Losses 50: 0.012214
# Train Epoch: 56 [25000/50000 (50%)]	Losses 50: 0.014126
# Train Epoch: 56 [50000/50000 (100%)]	Losses 50: 0.013247
# Test set:
# 50: loss: 0.0139	pho_loss: 0.0000004075
#
# Train Epoch: 57 [0/50000 (0%)]	Losses 50: 0.010608
# Train Epoch: 57 [25000/50000 (50%)]	Losses 50: 0.012206
# Train Epoch: 57 [50000/50000 (100%)]	Losses 50: 0.013152
# Test set:
# 50: loss: 0.0136	pho_loss: 0.0000003857
#
# Train Epoch: 58 [0/50000 (0%)]	Losses 50: 0.012487
# Train Epoch: 58 [25000/50000 (50%)]	Losses 50: 0.013413
# Train Epoch: 58 [50000/50000 (100%)]	Losses 50: 0.011858
# Test set:
# 50: loss: 0.0137	pho_loss: 0.0000004035
#
# Train Epoch: 59 [0/50000 (0%)]	Losses 50: 0.010787
# Train Epoch: 59 [25000/50000 (50%)]	Losses 50: 0.012211
# Train Epoch: 59 [50000/50000 (100%)]	Losses 50: 0.012298
# Test set:
# 50: loss: 0.0134	pho_loss: 0.0000003856
#
# Train Epoch: 60 [0/50000 (0%)]	Losses 50: 0.010947
# Train Epoch: 60 [25000/50000 (50%)]	Losses 50: 0.012758
# Train Epoch: 60 [50000/50000 (100%)]	Losses 50: 0.011110
# Test set:
# 50: loss: 0.0134	pho_loss: 0.0000003787
#
# Train Epoch: 61 [0/50000 (0%)]	Losses 50: 0.012019
# Train Epoch: 61 [25000/50000 (50%)]	Losses 50: 0.011042
# Train Epoch: 61 [50000/50000 (100%)]	Losses 50: 0.010968
# Test set:
# 50: loss: 0.0134	pho_loss: 0.0000003861
#
# Train Epoch: 62 [0/50000 (0%)]	Losses 50: 0.013413
# Train Epoch: 62 [25000/50000 (50%)]	Losses 50: 0.011508
# Train Epoch: 62 [50000/50000 (100%)]	Losses 50: 0.010770
# Test set:
# 50: loss: 0.0133	pho_loss: 0.0000003965
#
# Train Epoch: 63 [0/50000 (0%)]	Losses 50: 0.011323
# Train Epoch: 63 [25000/50000 (50%)]	Losses 50: 0.010821
# Train Epoch: 63 [50000/50000 (100%)]	Losses 50: 0.011663
# Test set:
# 50: loss: 0.0131	pho_loss: 0.0000003769
#
# Train Epoch: 64 [0/50000 (0%)]	Losses 50: 0.012215
# Train Epoch: 64 [25000/50000 (50%)]	Losses 50: 0.010803
# Train Epoch: 64 [50000/50000 (100%)]	Losses 50: 0.010386
# Test set:
# 50: loss: 0.0132	pho_loss: 0.0000003822
#
# Train Epoch: 65 [0/50000 (0%)]	Losses 50: 0.012760
# Train Epoch: 65 [25000/50000 (50%)]	Losses 50: 0.012559
# Train Epoch: 65 [50000/50000 (100%)]	Losses 50: 0.009792
# Test set:
# 50: loss: 0.0131	pho_loss: 0.0000003709
#
# Train Epoch: 66 [0/50000 (0%)]	Losses 50: 0.010675
# Train Epoch: 66 [25000/50000 (50%)]	Losses 50: 0.010312
# Train Epoch: 66 [50000/50000 (100%)]	Losses 50: 0.011332
# Test set:
# 50: loss: 0.0132	pho_loss: 0.0000003799
#
# Train Epoch: 67 [0/50000 (0%)]	Losses 50: 0.009777
# Train Epoch: 67 [25000/50000 (50%)]	Losses 50: 0.010498
# Train Epoch: 67 [50000/50000 (100%)]	Losses 50: 0.010424
# Test set:
# 50: loss: 0.0130	pho_loss: 0.0000003665
#
# Train Epoch: 68 [0/50000 (0%)]	Losses 50: 0.011445
# Train Epoch: 68 [25000/50000 (50%)]	Losses 50: 0.011729
# Train Epoch: 68 [50000/50000 (100%)]	Losses 50: 0.013314
# Test set:
# 50: loss: 0.0130	pho_loss: 0.0000003663
#
# Train Epoch: 69 [0/50000 (0%)]	Losses 50: 0.011107
# Train Epoch: 69 [25000/50000 (50%)]	Losses 50: 0.011907
# Train Epoch: 69 [50000/50000 (100%)]	Losses 50: 0.011935
# Test set:
# 50: loss: 0.0129	pho_loss: 0.0000003589
#
# Train Epoch: 70 [0/50000 (0%)]	Losses 50: 0.010775
# Train Epoch: 70 [25000/50000 (50%)]	Losses 50: 0.011667
# Train Epoch: 70 [50000/50000 (100%)]	Losses 50: 0.011924
# Test set:
# 50: loss: 0.0127	pho_loss: 0.0000003651
#
# Train Epoch: 71 [0/50000 (0%)]	Losses 50: 0.011189
# Train Epoch: 71 [25000/50000 (50%)]	Losses 50: 0.011365
# Train Epoch: 71 [50000/50000 (100%)]	Losses 50: 0.010748
# Test set:
# 50: loss: 0.0128	pho_loss: 0.0000003630
#
# Train Epoch: 72 [0/50000 (0%)]	Losses 50: 0.011349
# Train Epoch: 72 [25000/50000 (50%)]	Losses 50: 0.010774
# Train Epoch: 72 [50000/50000 (100%)]	Losses 50: 0.012931
# Test set:
# 50: loss: 0.0129	pho_loss: 0.0000003689
#
# Train Epoch: 73 [0/50000 (0%)]	Losses 50: 0.012322
# Train Epoch: 73 [25000/50000 (50%)]	Losses 50: 0.009524
# Train Epoch: 73 [50000/50000 (100%)]	Losses 50: 0.010022
# Test set:
# 50: loss: 0.0126	pho_loss: 0.0000003529
#
# Train Epoch: 74 [0/50000 (0%)]	Losses 50: 0.011785
# Train Epoch: 74 [25000/50000 (50%)]	Losses 50: 0.010642
# Train Epoch: 74 [50000/50000 (100%)]	Losses 50: 0.010883
# Test set:
# 50: loss: 0.0126	pho_loss: 0.0000003552
#
# Train Epoch: 75 [0/50000 (0%)]	Losses 50: 0.011031
# Train Epoch: 75 [25000/50000 (50%)]	Losses 50: 0.009081
# Train Epoch: 75 [50000/50000 (100%)]	Losses 50: 0.011443
# Test set:
# 50: loss: 0.0126	pho_loss: 0.0000003483
#
# Train Epoch: 76 [0/50000 (0%)]	Losses 50: 0.009525
# Train Epoch: 76 [25000/50000 (50%)]	Losses 50: 0.010532
# Train Epoch: 76 [50000/50000 (100%)]	Losses 50: 0.010674
# Test set:
# 50: loss: 0.0126	pho_loss: 0.0000003517
#
# Train Epoch: 77 [0/50000 (0%)]	Losses 50: 0.012182
# Train Epoch: 77 [25000/50000 (50%)]	Losses 50: 0.011863
# Train Epoch: 77 [50000/50000 (100%)]	Losses 50: 0.011173
# Test set:
# 50: loss: 0.0125	pho_loss: 0.0000003498
#
# Train Epoch: 78 [0/50000 (0%)]	Losses 50: 0.010792
# Train Epoch: 78 [25000/50000 (50%)]	Losses 50: 0.011738
# Train Epoch: 78 [50000/50000 (100%)]	Losses 50: 0.010380
# Test set:
# 50: loss: 0.0125	pho_loss: 0.0000003500
#
# Train Epoch: 79 [0/50000 (0%)]	Losses 50: 0.010870
# Train Epoch: 79 [25000/50000 (50%)]	Losses 50: 0.012152
# Train Epoch: 79 [50000/50000 (100%)]	Losses 50: 0.010774
# Test set:
# 50: loss: 0.0125	pho_loss: 0.0000003434
#
# Train Epoch: 80 [0/50000 (0%)]	Losses 50: 0.010522
# Train Epoch: 80 [25000/50000 (50%)]	Losses 50: 0.009392
# Train Epoch: 80 [50000/50000 (100%)]	Losses 50: 0.011190
# Test set:
# 50: loss: 0.0125	pho_loss: 0.0000003445
#
# Train Epoch: 81 [0/50000 (0%)]	Losses 50: 0.010717
# Train Epoch: 81 [25000/50000 (50%)]	Losses 50: 0.010567
# Train Epoch: 81 [50000/50000 (100%)]	Losses 50: 0.009276
# Test set:
# 50: loss: 0.0124	pho_loss: 0.0000003547
#
# Train Epoch: 82 [0/50000 (0%)]	Losses 50: 0.010456
# Train Epoch: 82 [25000/50000 (50%)]	Losses 50: 0.012160
# Train Epoch: 82 [50000/50000 (100%)]	Losses 50: 0.012020
# Test set:
# 50: loss: 0.0125	pho_loss: 0.0000003463
#
# Train Epoch: 83 [0/50000 (0%)]	Losses 50: 0.010179
# Train Epoch: 83 [25000/50000 (50%)]	Losses 50: 0.008917
# Train Epoch: 83 [50000/50000 (100%)]	Losses 50: 0.010774
# Test set:
# 50: loss: 0.0122	pho_loss: 0.0000003379
#
# Train Epoch: 84 [0/50000 (0%)]	Losses 50: 0.010606
# Train Epoch: 84 [25000/50000 (50%)]	Losses 50: 0.011977
# Train Epoch: 84 [50000/50000 (100%)]	Losses 50: 0.010889
# Test set:
# 50: loss: 0.0122	pho_loss: 0.0000003331
#
# Train Epoch: 85 [0/50000 (0%)]	Losses 50: 0.009775
# Train Epoch: 85 [25000/50000 (50%)]	Losses 50: 0.009933
# Train Epoch: 85 [50000/50000 (100%)]	Losses 50: 0.009496
# Test set:
# 50: loss: 0.0122	pho_loss: 0.0000003292
#
# Train Epoch: 86 [0/50000 (0%)]	Losses 50: 0.010328
# Train Epoch: 86 [25000/50000 (50%)]	Losses 50: 0.009668
# Train Epoch: 86 [50000/50000 (100%)]	Losses 50: 0.011700
# Test set:
# 50: loss: 0.0122	pho_loss: 0.0000003357
#
# Train Epoch: 87 [0/50000 (0%)]	Losses 50: 0.010495
# Train Epoch: 87 [25000/50000 (50%)]	Losses 50: 0.011184
# Train Epoch: 87 [50000/50000 (100%)]	Losses 50: 0.010432
# Test set:
# 50: loss: 0.0121	pho_loss: 0.0000003283
#
# Train Epoch: 88 [0/50000 (0%)]	Losses 50: 0.010644
# Train Epoch: 88 [25000/50000 (50%)]	Losses 50: 0.011342
# Train Epoch: 88 [50000/50000 (100%)]	Losses 50: 0.011237
# Test set:
# 50: loss: 0.0122	pho_loss: 0.0000003299
#
# Train Epoch: 89 [0/50000 (0%)]	Losses 50: 0.010916
# Train Epoch: 89 [25000/50000 (50%)]	Losses 50: 0.010650
# Train Epoch: 89 [50000/50000 (100%)]	Losses 50: 0.010841
# Test set:
# 50: loss: 0.0121	pho_loss: 0.0000003355
#
# Train Epoch: 90 [0/50000 (0%)]	Losses 50: 0.009524
# Train Epoch: 90 [25000/50000 (50%)]	Losses 50: 0.009712
# Train Epoch: 90 [50000/50000 (100%)]	Losses 50: 0.010168
# Test set:
# 50: loss: 0.0121	pho_loss: 0.0000003299
#
# Train Epoch: 91 [0/50000 (0%)]	Losses 50: 0.011681
# Train Epoch: 91 [25000/50000 (50%)]	Losses 50: 0.010633
# Train Epoch: 91 [50000/50000 (100%)]	Losses 50: 0.010138
# Test set:
# 50: loss: 0.0121	pho_loss: 0.0000003318
#
# Train Epoch: 92 [0/50000 (0%)]	Losses 50: 0.010192
# Train Epoch: 92 [25000/50000 (50%)]	Losses 50: 0.010164
# Train Epoch: 92 [50000/50000 (100%)]	Losses 50: 0.009964
# Test set:
# 50: loss: 0.0120	pho_loss: 0.0000003231
#
# Train Epoch: 93 [0/50000 (0%)]	Losses 50: 0.009582
# Train Epoch: 93 [25000/50000 (50%)]	Losses 50: 0.010106
# Train Epoch: 93 [50000/50000 (100%)]	Losses 50: 0.010415
# Test set:
# 50: loss: 0.0121	pho_loss: 0.0000003260
#
# Train Epoch: 94 [0/50000 (0%)]	Losses 50: 0.012072
# Train Epoch: 94 [25000/50000 (50%)]	Losses 50: 0.010190
# Train Epoch: 94 [50000/50000 (100%)]	Losses 50: 0.010191
# Test set:
# 50: loss: 0.0120	pho_loss: 0.0000003134
#
# Train Epoch: 95 [0/50000 (0%)]	Losses 50: 0.010706
# Train Epoch: 95 [25000/50000 (50%)]	Losses 50: 0.010732
# Train Epoch: 95 [50000/50000 (100%)]	Losses 50: 0.010512
# Test set:
# 50: loss: 0.0120	pho_loss: 0.0000003218
#
# Train Epoch: 96 [0/50000 (0%)]	Losses 50: 0.010031
# Train Epoch: 96 [25000/50000 (50%)]	Losses 50: 0.010362
# Train Epoch: 96 [50000/50000 (100%)]	Losses 50: 0.010674
# Test set:
# 50: loss: 0.0119	pho_loss: 0.0000003214
#
# Train Epoch: 97 [0/50000 (0%)]	Losses 50: 0.010489
# Train Epoch: 97 [25000/50000 (50%)]	Losses 50: 0.008785
# Train Epoch: 97 [50000/50000 (100%)]	Losses 50: 0.009173
# Test set:
# 50: loss: 0.0119	pho_loss: 0.0000003200
#
# Train Epoch: 98 [0/50000 (0%)]	Losses 50: 0.010825
# Train Epoch: 98 [25000/50000 (50%)]	Losses 50: 0.010896
# Train Epoch: 98 [50000/50000 (100%)]	Losses 50: 0.008892
# Test set:
# 50: loss: 0.0120	pho_loss: 0.0000003119
#
# Train Epoch: 99 [0/50000 (0%)]	Losses 50: 0.009412
# Train Epoch: 99 [25000/50000 (50%)]	Losses 50: 0.009964
# Train Epoch: 99 [50000/50000 (100%)]	Losses 50: 0.011416
# Test set:
# 50: loss: 0.0118	pho_loss: 0.0000003226
#
# Train Epoch: 100 [0/50000 (0%)]	Losses 50: 0.009825
# Train Epoch: 100 [25000/50000 (50%)]	Losses 50: 0.011650
# Train Epoch: 100 [50000/50000 (100%)]	Losses 50: 0.011139
# Test set:
# 50: loss: 0.0118	pho_loss: 0.0000003226
#
# Train Epoch: 101 [0/50000 (0%)]	Losses 50: 0.009760
# Train Epoch: 101 [25000/50000 (50%)]	Losses 50: 0.009121
# Train Epoch: 101 [50000/50000 (100%)]	Losses 50: 0.010555
# Test set:
# 50: loss: 0.0118	pho_loss: 0.0000003184
#
# Train Epoch: 102 [0/50000 (0%)]	Losses 50: 0.009749
# Train Epoch: 102 [25000/50000 (50%)]	Losses 50: 0.010560
# Train Epoch: 102 [50000/50000 (100%)]	Losses 50: 0.008732
# Test set:
# 50: loss: 0.0119	pho_loss: 0.0000003188
#
# Train Epoch: 103 [0/50000 (0%)]	Losses 50: 0.008922
# Train Epoch: 103 [25000/50000 (50%)]	Losses 50: 0.010222
# Train Epoch: 103 [50000/50000 (100%)]	Losses 50: 0.009443
# Test set:
# 50: loss: 0.0118	pho_loss: 0.0000003115
#
# Train Epoch: 104 [0/50000 (0%)]	Losses 50: 0.009827
# Train Epoch: 104 [25000/50000 (50%)]	Losses 50: 0.009266
# Train Epoch: 104 [50000/50000 (100%)]	Losses 50: 0.009828
# Test set:
# 50: loss: 0.0118	pho_loss: 0.0000003143
#
# Train Epoch: 105 [0/50000 (0%)]	Losses 50: 0.010171
# Train Epoch: 105 [25000/50000 (50%)]	Losses 50: 0.009777
# Train Epoch: 105 [50000/50000 (100%)]	Losses 50: 0.009822
# Test set:
# 50: loss: 0.0116	pho_loss: 0.0000003122
#
# Train Epoch: 106 [0/50000 (0%)]	Losses 50: 0.009096
# Train Epoch: 106 [25000/50000 (50%)]	Losses 50: 0.010186
# Train Epoch: 106 [50000/50000 (100%)]	Losses 50: 0.010558
# Test set:
# 50: loss: 0.0117	pho_loss: 0.0000003149
#
# Train Epoch: 107 [0/50000 (0%)]	Losses 50: 0.009131
# Train Epoch: 107 [25000/50000 (50%)]	Losses 50: 0.009315
# Train Epoch: 107 [50000/50000 (100%)]	Losses 50: 0.010125
# Test set:
# 50: loss: 0.0118	pho_loss: 0.0000003173
#
# Train Epoch: 108 [0/50000 (0%)]	Losses 50: 0.007784
# Train Epoch: 108 [25000/50000 (50%)]	Losses 50: 0.009481
# Train Epoch: 108 [50000/50000 (100%)]	Losses 50: 0.009547
# Test set:
# 50: loss: 0.0117	pho_loss: 0.0000003047
#
# Train Epoch: 109 [0/50000 (0%)]	Losses 50: 0.010239
# Train Epoch: 109 [25000/50000 (50%)]	Losses 50: 0.011224
# Train Epoch: 109 [50000/50000 (100%)]	Losses 50: 0.010592
# Test set:
# 50: loss: 0.0116	pho_loss: 0.0000003045
#
# Train Epoch: 110 [0/50000 (0%)]	Losses 50: 0.008498
# Train Epoch: 110 [25000/50000 (50%)]	Losses 50: 0.010397
# Train Epoch: 110 [50000/50000 (100%)]	Losses 50: 0.008970
# Test set:
# 50: loss: 0.0116	pho_loss: 0.0000003071
#
# Train Epoch: 111 [0/50000 (0%)]	Losses 50: 0.010538
# Train Epoch: 111 [25000/50000 (50%)]	Losses 50: 0.008572
# Train Epoch: 111 [50000/50000 (100%)]	Losses 50: 0.008393
# Test set:
# 50: loss: 0.0116	pho_loss: 0.0000003147
#
# Train Epoch: 112 [0/50000 (0%)]	Losses 50: 0.008961
# Train Epoch: 112 [25000/50000 (50%)]	Losses 50: 0.009011
# Train Epoch: 112 [50000/50000 (100%)]	Losses 50: 0.009891
# Test set:
# 50: loss: 0.0115	pho_loss: 0.0000003044
#
# Train Epoch: 113 [0/50000 (0%)]	Losses 50: 0.009128
# Train Epoch: 113 [25000/50000 (50%)]	Losses 50: 0.009219
# Train Epoch: 113 [50000/50000 (100%)]	Losses 50: 0.009432
# Test set:
# 50: loss: 0.0116	pho_loss: 0.0000003087
#
# Train Epoch: 114 [0/50000 (0%)]	Losses 50: 0.009988
# Train Epoch: 114 [25000/50000 (50%)]	Losses 50: 0.011049
# Train Epoch: 114 [50000/50000 (100%)]	Losses 50: 0.011443
# Test set:
# 50: loss: 0.0116	pho_loss: 0.0000003072
#
# Train Epoch: 115 [0/50000 (0%)]	Losses 50: 0.010075
# Train Epoch: 115 [25000/50000 (50%)]	Losses 50: 0.009058
# Train Epoch: 115 [50000/50000 (100%)]	Losses 50: 0.010023
# Test set:
# 50: loss: 0.0115	pho_loss: 0.0000002963
#
# Train Epoch: 116 [0/50000 (0%)]	Losses 50: 0.010027
# Train Epoch: 116 [25000/50000 (50%)]	Losses 50: 0.008612
# Train Epoch: 116 [50000/50000 (100%)]	Losses 50: 0.009216
# Test set:
# 50: loss: 0.0115	pho_loss: 0.0000002943
#
# Train Epoch: 117 [0/50000 (0%)]	Losses 50: 0.009804
# Train Epoch: 117 [25000/50000 (50%)]	Losses 50: 0.009004
# Train Epoch: 117 [50000/50000 (100%)]	Losses 50: 0.009613
# Test set:
# 50: loss: 0.0116	pho_loss: 0.0000002974
#
# Train Epoch: 118 [0/50000 (0%)]	Losses 50: 0.009536
# Train Epoch: 118 [25000/50000 (50%)]	Losses 50: 0.010108
# Train Epoch: 118 [50000/50000 (100%)]	Losses 50: 0.010176
# Test set:
# 50: loss: 0.0115	pho_loss: 0.0000002985
#
# Train Epoch: 119 [0/50000 (0%)]	Losses 50: 0.009060
# Train Epoch: 119 [25000/50000 (50%)]	Losses 50: 0.009514
# Train Epoch: 119 [50000/50000 (100%)]	Losses 50: 0.010285
# Test set:
# 50: loss: 0.0116	pho_loss: 0.0000002943
#
# Train Epoch: 120 [0/50000 (0%)]	Losses 50: 0.010443
# Train Epoch: 120 [25000/50000 (50%)]	Losses 50: 0.010203
# Train Epoch: 120 [50000/50000 (100%)]	Losses 50: 0.009619
# Test set:
# 50: loss: 0.0114	pho_loss: 0.0000002915
#
# Train Epoch: 121 [0/50000 (0%)]	Losses 50: 0.009224
# Train Epoch: 121 [25000/50000 (50%)]	Losses 50: 0.009609
# Train Epoch: 121 [50000/50000 (100%)]	Losses 50: 0.009010
# Test set:
# 50: loss: 0.0114	pho_loss: 0.0000002918
#
# Train Epoch: 122 [0/50000 (0%)]	Losses 50: 0.009303
# Train Epoch: 122 [25000/50000 (50%)]	Losses 50: 0.009593

# %%
torch.save(models['50'], './model_50_tanh')

# %% [markdown]
# ### Вывод результатов

# %%
model = torch.load('./model_50_tanh')

# %%
data, _ = next(iter(test_loader))
output = model(data)
to_plot = output.view(-1, 1, 28, 28).clamp(-1, 1).data.numpy()
decoded = model.decode(torch.eye(50))
dec_to_plot = decoded.view(-1, 1, 28, 28).clamp(-1, 1).data.numpy()
with torch.no_grad():
    encoded = model.E(data.view(-1, 28*28))
    print ("encoded=",encoded)
    print((abs(encoded) > 0.02).sum(1))
    encoded[abs(encoded) < 0.02] = 0.
    decoded_f = model.decode(encoded)
    f_to_plot = ((decoded_f.view(-1, 1, 28, 28)+1)*0.5).clamp(-1, 1).data.numpy()

# %%
print ("Исходные данные")
plot_mnist(data.data.numpy(), (5, 10))
print ("Выход декодера")
plot_mnist(to_plot, (5, 10))
print ("Выход декодера с отсечкой на латентном слое")
plot_mnist(f_to_plot, (5, 10))
print ("Выход декодера с единичной матрицы")
plot_mnist(dec_to_plot, (5, 10))

# %% [markdown]
# ### Генерация изображений на вход энкодера

# %%
from torch.autograd import Variable

def generate_image(img):
    
    gen_img_par = Variable(img, requires_grad=True)
    latent_vector = torch.eye(50)
    loss_stats = []
    
    gen_optim = optim.Adam([gen_img_par], lr=1e-3, weight_decay=0.)

    for i in range(1, 500001):  
                
        target = model.E(gen_img_par.view(-1, 28*28))
                
        gen_optim.zero_grad()
        loss = F.mse_loss(target, latent_vector)    
        loss.backward()                   
        gen_optim.step()
        
        if i % 20000 == 0:    
            print ("Iteration {}: loss={}".format(i,loss))
            ls = loss.detach().numpy()            
            loss_stats.append(ls)
                        
            if len(loss_stats) > 5:    
                if ls > loss_stats[-2] and ls > loss_stats[-3]:
                    print ("Loss is rising .. stop")
                    break

        if i % 100000 == 0:
            to_plot = gen_img_par.view(-1, 1, 28, 28).clamp(-1, 1).data.numpy()
            plot_mnist(to_plot, (5, 10))
                        
    return gen_img_par

# %%
img, _ = next(iter(test_loader))
to_plot = img.view(-1, 1, 28, 28).clamp(-1, 1).data.numpy()
plot_mnist(to_plot, (5, 10))
new_image_batch = generate_image(img)

# %%
data, _ = next(iter(test_loader))
latent = model.E(data.view(-1, 28*28))
print (latent.shape)
print (latent)

# %%
to_plot = latent.view(-1, 1, 5, 10).clamp(-1, 1).data.numpy()
plot_mnist(to_plot, (5, 10))
